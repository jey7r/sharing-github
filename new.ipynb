# %%
import pandas as pd
import numpy as np
df=pd.read_excel('/Users/hopper/Downloads/marks.xlsx')
df.head()
# Out:
#    sr no  marks
# 0      1   15.0
# 1      2   26.0
# 2      3   46.0
# 3      4   12.0
# 4      5   58.0

# %%
# df.loc[df['marks']>=50, 'result']='pass'
# df.loc[df['marks']<50, 'result']='fail'
# df
# df['result']=df['marks'].apply(lambda x: 'pass' if x>=50 else 'fail')
# df

df['result'] = np.where(df['marks']>=50, 'pass', 'fail')
df
# Out:
#     sr no      marks result
# 0       1  15.000000   fail
# 1       2  26.000000   fail
# 2       3  46.000000   fail
# 3       4  12.000000   fail
# 4       5  58.000000   pass
# 5       6  87.000000   pass
# 6       7  65.000000   pass
# 7       8  54.000000   pass
# 8       9  76.000000   pass
# 9      10  43.000000   fail
# 10     11  23.000000   fail
# 11     12  45.000000   fail
# 12     13  58.742424   pass
# 13     14  60.728438   pass
# 14     15  62.714452   pass
# 15     16  64.700466   pass
# 16     17  66.686480   pass
# 17     18  68.672494   pass
# 18     19  70.658508   pass
# 19     20  72.644522   pass
# 20     21  74.630536   pass
# 21     22  76.616550   pass
# 22     23  78.602564   pass
# 23     24  80.588578   pass
# 24     25  82.574592   pass
# 25     26  84.560606   pass
# 26     27  58.000000   pass
# 27     28  88.532634   pass
# 28     29  90.518648   pass
# 29     30  92.504662   pass
# 30     31  56.000000   pass
# 31     32  34.000000   fail
# ...

# %%
df['result'] = np.where(df['marks']>=50, 'pass', np.where(df['marks']>=30, 'compartment', 'fail'))
df
# Out:
#     sr no      marks       result
# 0       1  15.000000         fail
# 1       2  26.000000         fail
# 2       3  46.000000  compartment
# 3       4  12.000000         fail
# 4       5  58.000000         pass
# 5       6  87.000000         pass
# 6       7  65.000000         pass
# 7       8  54.000000         pass
# 8       9  76.000000         pass
# 9      10  43.000000  compartment
# 10     11  23.000000         fail
# 11     12  45.000000  compartment
# 12     13  58.742424         pass
# 13     14  60.728438         pass
# 14     15  62.714452         pass
# 15     16  64.700466         pass
# 16     17  66.686480         pass
# 17     18  68.672494         pass
# 18     19  70.658508         pass
# 19     20  72.644522         pass
# 20     21  74.630536         pass
# 21     22  76.616550         pass
# 22     23  78.602564         pass
# 23     24  80.588578         pass
# 24     25  82.574592         pass
# 25     26  84.560606         pass
# ...

# %%
df['percentage'] = df['marks']/100*100
df
# Out:
#     sr no      marks       result  percentage
# 0       1  15.000000         fail   15.000000
# 1       2  26.000000         fail   26.000000
# 2       3  46.000000  compartment   46.000000
# 3       4  12.000000         fail   12.000000
# 4       5  58.000000         pass   58.000000
# 5       6  87.000000         pass   87.000000
# 6       7  65.000000         pass   65.000000
# 7       8  54.000000         pass   54.000000
# 8       9  76.000000         pass   76.000000
# 9      10  43.000000  compartment   43.000000
# 10     11  23.000000         fail   23.000000
# 11     12  45.000000  compartment   45.000000
# 12     13  58.742424         pass   58.742424
# 13     14  60.728438         pass   60.728438
# 14     15  62.714452         pass   62.714452
# 15     16  64.700466         pass   64.700466
# 16     17  66.686480         pass   66.686480
# 17     18  68.672494         pass   68.672494
# 18     19  70.658508         pass   70.658508
# ...

# %%
df = pd.read_excel('/Users/hopper/Downloads/Class 10A (IF Formula).xlsx', sheet_name='Exp 1')
df.head()
# Out:
#    Sr no Student name Class  Hindi  English   Math   S.S.T  Science  Total  \
# 0      1        Sahil  10th     75        77     65     78       65    360
# 1      2         Saba  10th     60        67     70     68       75    340
# 2      3        Naved  10th     50        60     58     60       59    287
# 3      4       Shawez  10th     70         6     45      6        6    133
# 4      5        Saima  10th     50        67     49     69       40    275
#
#    Percentage Result Division Grade  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0        72.0   Pass    First    B+          NaN          NaN          NaN
# 1        68.0   Pass    First     B          NaN          NaN         60.0
# 2        57.4   Pass   Second    C+          NaN          NaN         45.0
# 3        26.6   fail     fail  Fail          NaN          NaN         33.0
# 4        55.0   Pass   Second    C+          NaN          NaN          NaN
#
#   Unnamed: 16
# 0         NaN
# 1       First
# 2      Second
# ...

# %%
df.drop(['Total', 'Percentage', 'Result', 'Division', 'Grade', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Sr no Student name Class  Hindi  English   Math   S.S.T  Science
# 0      1        Sahil  10th     75        77     65     78       65
# 1      2         Saba  10th     60        67     70     68       75
# 2      3        Naved  10th     50        60     58     60       59
# 3      4       Shawez  10th     70         6     45      6        6
# 4      5        Saima  10th     50        67     49     69       40

# %%
df.columns
# Out:
# Index(['Sr no', 'Student name', 'Class', 'Hindi', 'English ', 'Math ', 'S.S.T',
#        'Science'],
#       dtype='object')

# %%
df['Total'] = df['Math '] + df['Science'] + df['English '] + df['Hindi'] + df['S.S.T']

# %%
df['Percentage'] = df['Total']/500*100

# %%
df['Result']=np.where(df['Percentage']>=33, 'pass', 'fail')

# %%
df['Division'] = np.where(df['Percentage']>=60, 'First', np.where(df['Percentage']>=45, 'Second', 'Third'))

# %%
df['Grade'] = np.where(df['Percentage']>=90, 'A+', np.where(df['Percentage']>=80, 'A', np.where(df['Percentage']>=70, 'B', np.where(df['Percentage']>=60, 'C', np.where(df['Percentage']>=50, 'D', 'E')))))

# %%
df
# Out:
#     Sr no Student name Class  Hindi  English   Math   S.S.T  Science  Total  \
# 0       1        Sahil  10th     75        77     65     78       65    360
# 1       2         Saba  10th     60        67     70     68       75    340
# 2       3        Naved  10th     50        60     58     60       59    287
# 3       4       Shawez  10th     70         6     45      6        6    133
# 4       5        Saima  10th     50        67     49     69       40    275
# 5       6      Sameera  10th     67        69     58     55       76    325
# 6       7       Savita  10th     60        55     70     67       55    307
# 7       8       fareen  10th     58        60     66     75       48    307
# 8       9         Monu  10th     60         6      6      6        6     84
# 9      10        Shanu  10th     45        55     50     39       40    229
# 10     11       kashif  10th     45        68     49     58       69    289
# ...

# %%
df = pd.read_excel('/Users/hopper/Downloads/Class 10B (And+OR Formula).xlsx', sheet_name='Exp 1')
df
# Out:
#     S no. Employee Name  Salary  OT Performance Gift Status Mobile  \
# 0       1          Ajay   10798  22        Poor            No Gift
# 1       2         Irfan   20947  30     Average             Mobile
# 2       3          Khan   10890  34        Good             Mobile
# 3       4        Farhan   24863   8     Average            No Gift
# 4       5        Shoaib    8861  38        Poor             Mobile
# 5       6        Shilpa   11345  40        Poor             Mobile
# 6       7         Sahil    8338   1     Average             Mobile
# 7       8        Saurav    9752  26        Good             Mobile
# 8       9        Kashif    7128   3        Poor             Mobile
# 9      10         As if   10247   1        Good             Mobile
# 10     11          Alam   21705  17        Poor            No Gift
# 11     12         Amaan   11321  27     Average             Mobile
# 12     13        Nikhat   11862   9     Average            No Gift
# ...

# %%
df1=df[['Employee Name', 'Salary', 'OT', 'Performance']]
df1
# Out:
#    Employee Name  Salary  OT Performance
# 0           Ajay   10798  22        Poor
# 1          Irfan   20947  30     Average
# 2           Khan   10890  34        Good
# 3         Farhan   24863   8     Average
# 4         Shoaib    8861  38        Poor
# 5         Shilpa   11345  40        Poor
# 6          Sahil    8338   1     Average
# 7         Saurav    9752  26        Good
# 8         Kashif    7128   3        Poor
# 9          As if   10247   1        Good
# 10          Alam   21705  17        Poor
# 11         Amaan   11321  27     Average
# 12        Nikhat   11862   9     Average
# 13         Nisha   10110  47        Poor
# 14         Irfan    8792  20     Average
# 15          Khan    7457   8        Poor
# 16        Farhan    7819  42        Poor
# 17        Shoaib   15847  47     Average
# 18        Shilpa   21999  37        Poor
# 19         Sahil   11582  43        Good
# 20        Saurav   12084   6        Poor
# 21        Kashif    8165  38        Good
# ...

# %%
df1['Mobile'] = np.where((df['Salary'] <= 10000) & (df['OT'] >= 25) & (df['Performance'] == 'Good'), 'Yes', 'No Gift')
df1['Laptop'] = np.where((df['Salary'] >= 10000) & (df['OT'] >= 25) & (df['Performance'] == 'Good'), 'Yes', 'No Gift')
df1
# Out:
# /var/folders/d9/h6cyz7w16sb1rpc05yqgh1hm0000gn/T/ipykernel_50591/4281786837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Mobile'] = np.where((df['Salary'] <= 10000) & (df['OT'] >= 25) & (df['Performance'] == 'Good'), 'Yes', 'No Gift')
#    Employee Name  Salary  OT Performance   Mobile   Laptop
# 0           Ajay   10798  22        Poor  No Gift  No Gift
# 1          Irfan   20947  30     Average  No Gift  No Gift
# 2           Khan   10890  34        Good  No Gift      Yes
# 3         Farhan   24863   8     Average  No Gift  No Gift
# 4         Shoaib    8861  38        Poor  No Gift  No Gift
# 5         Shilpa   11345  40        Poor  No Gift  No Gift
# 6          Sahil    8338   1     Average  No Gift  No Gift
# ...

# %%
df= pd.read_excel('/Users/hopper/Downloads/Class 10B (And+OR Formula).xlsx', sheet_name='Exp 2')
df
# Out:
#     S no. Stu Name  10th  12th  Test Marks       4K Status      30K Status  \
# 0       1     Ajay    89    84          97            4000  No Scholarship
# 1       2    Irfan    76    96          76            4000  No Scholarship
# 2       3     Khan    92    75          83            4000  No Scholarship
# 3       4   Farhan    91    77          96            4000  No Scholarship
# 4       5   Shoaib    96    94          95            4000           30000
# 5       6   Shilpa    97    78          98            4000  No Scholarship
# 6       7    Sahil    87    81          91            4000  No Scholarship
# 7       8   Saurav    84    96          82            4000  No Scholarship
# 8       9   Kashif    92    91          93            4000           30000
# 9      10    As if    86    77          93            4000  No Scholarship
# 10     11     Alam    81    77          99            4000  No Scholarship
# ...

# %%
df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', '4K Status', '30K Status'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    S no. Stu Name  10th  12th  Test Marks
# 0      1     Ajay    89    84          97
# 1      2    Irfan    76    96          76
# 2      3     Khan    92    75          83
# 3      4   Farhan    91    77          96
# 4      5   Shoaib    96    94          95

# %%
df['Scholarship'] = np.where((df['10th'] >= 92) & (df['12th'] >= 88) & (df['Test Marks'] >= 92), '30000', np.where((df['10th'] >= 91) & (df['12th'] >= 85) & (df['Test Marks'] >= 91), '4000', 'No Scholarship'))
df
# Out:
#     S no. Stu Name  10th  12th  Test Marks     Scholarship
# 0       1     Ajay    89    84          97  No Scholarship
# 1       2    Irfan    76    96          76  No Scholarship
# 2       3     Khan    92    75          83  No Scholarship
# 3       4   Farhan    91    77          96  No Scholarship
# 4       5   Shoaib    96    94          95           30000
# 5       6   Shilpa    97    78          98  No Scholarship
# 6       7    Sahil    87    81          91  No Scholarship
# 7       8   Saurav    84    96          82  No Scholarship
# 8       9   Kashif    92    91          93           30000
# 9      10    As if    86    77          93  No Scholarship
# 10     11     Alam    81    77          99  No Scholarship
# 11     12    Amaan    93    82          76  No Scholarship
# 12     13   Nikhat    76    76          89  No Scholarship
# 13     14    Nisha    83    76          97  No Scholarship
# 14     15    Irfan    91    89          85  No Scholarship
# ...

# %%
df= pd.read_excel('/Users/hopper/Downloads/Class 10B (And+OR Formula).xlsx', sheet_name='Exp 5')
df.head()
# Out:
#    S no. Candidate Name Qualification  Exp  Expcted Sal Interview Remarks  \
# 0      1           Ajay           MBA    4        13015           Average
# 1      2          Irfan           bsw    3        18639         Excellent
# 2      3           Khan           MSW    1        12147           Average
# 3      4         Farhan           MBA    4        12180         Excellent
# 4      5         Shoaib           BBA    2        15806              Poor
#
#          Status  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0  Not Selected         NaN         NaN         NaN         NaN         NaN
# 1  Not Selected         NaN         NaN         NaN         NaN         NaN
# 2  Not Selected         NaN         NaN         NaN           Q         MBA
# 3      Selected         NaN         NaN         NaN         Exp         >=1
# 4  Not Selected         NaN         NaN         NaN          ES     <=18000

# %%
df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Status'], axis=1, inplace=True)

# %%
df['Selection Status'] = np.where(
    ((df['Qualification'] == 'MBA') | (df['Qualification'] == 'M.Com')) &
    (df['Exp'] >= 1) &
    (df['Expcted Sal'] <= 18000) &
    ((df['Interview Remarks'] == 'Excellent') | (df['Interview Remarks'] == 'Good')),
    'Selected',
    'Not Selected'
)

# %%
df
# Out:
#     S no. Candidate Name Qualification  Exp  Expcted Sal Interview Remarks  \
# 0       1           Ajay           MBA    4        13015           Average
# 1       2          Irfan           bsw    3        18639         Excellent
# 2       3           Khan           MSW    1        12147           Average
# 3       4         Farhan           MBA    4        12180         Excellent
# 4       5         Shoaib           BBA    2        15806              Poor
# ..    ...            ...           ...  ...          ...               ...
# 92     93         Nikhat           BCA    2        19694              Good
# 93     94          Nisha         B.com    5        10765         Excellent
# 94     95          Irfan           MSW    3        19514         Excellent
# 95     96           Khan         M.com    2        15064              Good
# 96     97         Farhan         B.com    2        11030           Average
#
#    Selection Status
# 0      Not Selected
# 1      Not Selected
# ...
