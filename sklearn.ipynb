# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df = pd.read_csv('/Users/hopper/Downloads/home price location.csv')
df
# Out:
#     area   price location
# 0   2600  550000   mumbai
# 1   2000  565000    delhi
# 2   3200  610000  kolkata
# 3   3600  680000   mumbai
# 4   4000  720000    delhi
# 5   2500  600000  kolkata
# 6   2700  650000   mumbai
# 7   3000  700000    delhi
# 8   3400  800000  kolkata
# 9   2600  550000   mumbai
# 10  2000  565000    delhi
# 11  3200  610000  kolkata
# 12  3600  680000   mumbai
# 13  4000  720000    delhi
# 14  2500  600000  kolkata
# 15  2700  650000   mumbai
# 16  3000  700000    delhi
# 17  3400  800000  kolkata
# 18  2600  550000   mumbai
# 19  2000  565000    delhi
# 20  3200  610000  kolkata
# 21  3600  680000   mumbai
# 22  4000  720000    delhi
# 23  2500  600000  kolkata
# 24  2700  650000   mumbai
# 25  3000  700000    delhi
# 26  3400  800000  kolkata

# %%
df_final = pd.get_dummies(df['location'],dtype=int)
df_final
# Out:
#     delhi  kolkata  mumbai
# 0       0        0       1
# 1       1        0       0
# 2       0        1       0
# 3       0        0       1
# 4       1        0       0
# 5       0        1       0
# 6       0        0       1
# 7       1        0       0
# 8       0        1       0
# 9       0        0       1
# 10      1        0       0
# 11      0        1       0
# 12      0        0       1
# 13      1        0       0
# 14      0        1       0
# 15      0        0       1
# 16      1        0       0
# 17      0        1       0
# 18      0        0       1
# 19      1        0       0
# 20      0        1       0
# 21      0        0       1
# 22      1        0       0
# 23      0        1       0
# 24      0        0       1
# 25      1        0       0
# 26      0        1       0

# %%
df1 = pd.concat([df, df_final], axis=1)
df1
# Out:
#     area   price location  delhi  kolkata  mumbai  delhi  kolkata  mumbai  \
# 0   2600  550000   mumbai      0        0       1      0        0       1
# 1   2000  565000    delhi      1        0       0      1        0       0
# 2   3200  610000  kolkata      0        1       0      0        1       0
# 3   3600  680000   mumbai      0        0       1      0        0       1
# 4   4000  720000    delhi      1        0       0      1        0       0
# 5   2500  600000  kolkata      0        1       0      0        1       0
# 6   2700  650000   mumbai      0        0       1      0        0       1
# 7   3000  700000    delhi      1        0       0      1        0       0
# 8   3400  800000  kolkata      0        1       0      0        1       0
# 9   2600  550000   mumbai      0        0       1      0        0       1
# 10  2000  565000    delhi      1        0       0      1        0       0
# 11  3200  610000  kolkata      0        1       0      0        1       0
# ...

# %%
x=[['area']]
y=['price']

# %%
x = df[['area', 'delhi', 'kolkata', 'mumbai']]
y = df['price']
lg = LinearRegression()
lg.fit(x, y)
# Out:
# LinearRegression()

# %%
lg.predict([[2800, 0, 0, 1]])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([611073.50800582])

# %%
import matplotlib.pyplot as plt

# %%
scatter1 = plt.scatter(df['area'], df['price'], color='red', marker='+')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lmplot(x='area', y='price', hue='location', data=df1)

plt.title('Price per Area in 3 Locations')
plt.show()
